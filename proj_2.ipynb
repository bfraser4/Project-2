# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#Extract CSVs into DataFrames
disney_file = "Resources/disney_plus_titles.csv"
disney_df = pd.read_csv(disney_file)
disney_df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
# extract CSV 2 into df
netflix_file = "Resources/netflix_titles.csv"
netflix_df = pd.read_csv(netflix_file)
netflix_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
# extract CSV 3 into df
imdb_file = "Resources/Top 1000 IMDB movies.csv"
imdb_df = pd.read_csv(imdb_file)
imdb_df.head()
# Out:
#    Unnamed: 0                                     Movie Name Year of Release  \
# 0           0                       The Shawshank Redemption          (1994)
# 1           1                                  The Godfather          (1972)
# 2           2                                The Dark Knight          (2008)
# 3           3  The Lord of the Rings: The Return of the King          (2003)
# 4           4                               Schindler's List          (1993)
#
#   Watch Time  Movie Rating Meatscore of movie   Votes     Gross  \
# 0    142 min           9.3         81          34,709   $28.34M
# 1    175 min           9.2        100          34,709  $134.97M
# 2    152 min           9.0         84          34,709  $534.86M
# 3    201 min           9.0         94          34,709  $377.85M
# 4    195 min           9.0         94          34,709   $96.90M
#
#                                          Description
# 0  Two imprisoned men bond over a number of years...
# ...

# %%
imdb_cols = ["Movie Name", "Movie Rating", "Votes"]
imbd_transformed= imdb_df[imdb_cols].copy()

# %%
imdb_transformed_title = imbd_transformed.rename(columns={"Movie Name": "title"})
imdb_transformed_title.head()
# Out:
#                                            title  Movie Rating   Votes
# 0                       The Shawshank Redemption           9.3  34,709
# 1                                  The Godfather           9.2  34,709
# 2                                The Dark Knight           9.0  34,709
# 3  The Lord of the Rings: The Return of the King           9.0  34,709
# 4                               Schindler's List           9.0  34,709

# %%
#Disney+ Create a  filtered dataframe from specific columns
disney_cols = ["title", "date_added", "rating"]
disney_transformed= disney_df[disney_cols].copy()

# %%
#netflix Create a  filtered dataframe from specific columns
netflix_cols = ["title", "date_added", "rating"]
netflix_transformed= netflix_df[netflix_cols].copy()
netflix_transformed.head()
# Out:
#                    title date_added rating
# 0   Dick Johnson Is Dead  25-Sep-21  PG-13
# 1          Blood & Water  24-Sep-21  TV-MA
# 2              Ganglands  24-Sep-21  TV-MA
# 3  Jailbirds New Orleans  24-Sep-21  TV-MA
# 4           Kota Factory  24-Sep-21  TV-MA

# %%
#merge
imdb_rating_merge= pd.merge(left=imdb_transformed_title,right=netflix_transformed, how = 'inner', on = "title")
#some function to show that we can change the data, dates ARE hard. please tell me how to change this kind of format  vvvvv
imdb_rating_merge['rating']=imdb_rating_merge['rating'].str.lower()
imdb_rating_merge.head(191)
# Out:
#                                               title  Movie Rating   Votes  \
# 0     The Lord of the Rings: The Return of the King           9.0  34,709
# 1                                  Schindler's List           9.0  34,709
# 2                                      Pulp Fiction           8.9  34,709
# 3                                         Inception           8.8  34,709
# 4             The Lord of the Rings: The Two Towers           8.8  34,709
# ..                                              ...           ...     ...
# 185  The Naked Gun: From the Files of Police Squad!           7.6  34,709
# 186                                Enter the Dragon           7.6  34,709
# 187                                 The Jungle Book           7.6  34,709
# 188                           Rebel Without a Cause           7.6  34,709
# 189                                         Sabrina           7.6  34,709
#
#     date_added rating
# 0     1-Jan-20  pg-13
# 1     1-Apr-18      r
# ...

# %%
#create database conn

connection_string = "postgres:postgres@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
protocol = 'postgresql'
username = 'XXXXXXX. git ignore file'
password = 'XXXXXXX. git ignore file'
host = 'localhost'
port = 5432
database_name = 'streaming_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
imdb_rating_merge.to_sql(name='stream_db', con=engine, if_exists='append', index=False)
# Out:
# 190
